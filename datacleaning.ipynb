# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\dhrit\\Downloads\\NFL Play by Play 2009-2016 (v3).csv", low_memory=False)
print( df.shape)
display(df.head())
# Out:
# (362447, 102)
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
df = df.drop_duplicates()
print( df.shape)
# Out:
# (362447, 102)

# %%
for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].str.strip().str.upper()
display(df.head(5))
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
placeholders = ["NA", "N/A", "NONE", "NULL", "NAN", "?", "-", "--", "UNKNOWN", "ERROR"]
for col in df.columns:
    df[col] = df[col].replace(placeholders, np.nan)
missing_table = df.isna().sum().sort_values(ascending=False).head(10).reset_index()
missing_table.columns = ["Column", "Missing Values"]
display(missing_table)
# Out:
#               Column  Missing Values
# 0        DefTwoPoint          362433
# 1     BlockingPlayer          362341
# 2       TwoPointConv          361919
# 3   ChalReplayResult          359476
# 4      RecFumbPlayer          358513
# 5        RecFumbTeam          358513
# 6        Interceptor          358387
# 7  FieldGoalDistance          354528
# 8    FieldGoalResult          354431
# 9      ExPointResult          353399

# %%
if "Date" in df.columns:
    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
dtypes_table = df.dtypes.head(10).reset_index()
dtypes_table.columns = ["Column", "Data Type"]
display(dtypes_table)
# Out:
#          Column       Data Type
# 0          Date  datetime64[ns]
# 1        GameID           int64
# 2         Drive           int64
# 3           qtr           int64
# 4          down         float64
# 5          time          object
# 6     TimeUnder           int64
# 7      TimeSecs         float64
# 8  PlayTimeDiff         float64
# 9   SideofField          object

# %%
display(df.head(10))
# Out:
#         Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0 2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1 2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2 2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3 2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4 2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# 5 2009-09-10  2009091000      2    1   1.0  13:16         14    3496.0
# 6 2009-09-10  2009091000      2    1   2.0  12:40         13    3460.0
# 7 2009-09-10  2009091000      2    1   3.0  12:11         13    3431.0
# 8 2009-09-10  2009091000      2    1   4.0  11:34         12    3394.0
# 9 2009-09-10  2009091000      3    1   1.0  11:24         12    3384.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# ...

# %%
display(df.describe().T)
# Out:
#              count                           mean                  min  \
# Date        362447  2013-05-15 01:23:13.100784128  2009-09-10 00:00:00
# GameID    362447.0              2012664429.993891         2009091000.0
# Drive     362447.0                      12.347088                  1.0
# qtr       362447.0                       2.578231                  1.0
# down      308229.0                       2.001226                  1.0
# ...            ...                            ...                  ...
# Win_Prob  340454.0                       0.501311                  0.0
# WPA       357630.0                       0.002163            -0.997214
# airWPA    141709.0                       0.015209            -0.999881
# yacWPA    141491.0                      -0.010492            -0.986673
# Season    362447.0                    2012.522071               2009.0
#
#                           25%                  50%                  75%  \
# ...
